# %% [markdown]
# # Workshop IV: From MyBinder to JupyterHub

# %% [markdown]
# We will visualise the life expectancy in Croatia from 1999 until 2016.

# %% [markdown]
# ## Data
#
# [Wikidata](https://www.wikidata.org) has the life expectancy in Croatia from 1999 until 2016. This data can be accessed at https://www.wikidata.org/wiki/Q224.
#
# For this short workshop, I manually copied the data from Wikidata into this Jupyter Notebook. Using an REST API call is also possible.
#
# Also, I used standard Python `list` to store the years and life expectancy. Using data frames from pandas is also possible.

# %%
years = [
    1999,
    2000,
    2001,
    2002,
    2003,
    2004,
    2005,
    2006,
    2007,
    2008,
    2009,
    2010,
    2011,
    2012,
    2013,
    2014,
    2015,
    2016
]

# %%
life_expectancy = [
    72.64195,
    72.8078,
    74.51293,
    74.71732,
    74.6139,
    75.52024,
    75.24463,
    75.83683,
    75.70561,
    75.9122,
    76.16829,
    76.47561,
    76.77561,
    76.92439,
    77.12683,
    77.47805,
    77.27561,
    78.02195
]

# %%
assert len(years) == len(life_expectancy)

# %% [markdown]
# ## Visualisation

# %% [markdown]
# Now is time to visualise the life expectancy.
#
# I used [matplotlib](https://matplotlib.org/) for this short workshop. [Plotly](https://plotly.com/), [seaborn](https://seaborn.pydata.org/), [Bokeh](https://docs.bokeh.org/), and [Vega-Altair](https://altair-viz.github.io/) are also supported in Jupyter Notebook.

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(years, life_expectancy)

# %% [markdown]
# With a couple of extra lines of code, we can improve the visualisation.

# %%
from matplotlib.ticker import MaxNLocator

# %%
# Use integers in the axis
ax = plt.figure().gca()
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.plot(years, life_expectancy)
plt.xlabel('Year')
plt.ylabel('Life Expectancy (in years)')
plt.title('Croatia')
# Out:
# Text(0.5, 1.0, 'Croatia')
